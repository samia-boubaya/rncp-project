# %% [markdown]
# <hr>
#
# # 🧫 DATA CLEANING
#
#
# <style>
# h1 {
#     text-align: left;
#     color: blue;
#     font-weight: bold;
# }
#
# </style>
# <hr>

# %% [markdown]
# ```text
# Steps to Data Cleaning:
# 0. Data Loading  (.txt and .json to .csv and merge if multiple sources)
# 1. Data exploration (understand data and note the changes to make)
# 2. Standardize columns names
# 3. Deal with invalid values
# 4. Convert data types
# 5. Deal with null values (fill, replace, median, drop)
# 6. Deal with duplicate values (keep or drop)
# 7. Check & Save clean CSV (../data/processed/clean_data.csv)
# ```

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 📂 IMPORTs

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200) # to display all columns in the dataframe

# %% [markdown]
# <hr>
#
# ## 0 - DATA LOADING
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔻 LOAD - DATASETS

# %%
# Load online_shoppers_intention.csv into a df DataFrame
df_flatfile = pd.read_csv("../data/raw/external_data.csv")
df_scraped = pd.read_csv("../data/raw/scraped_data.csv")

# standardize each DataFrame where necessary (variables in commun)

# Concat datasets
df = pd.concat([df_flatfile, df_scraped], ignore_index=True)

# Save the combined dataset to a new CSV file
df.to_csv("../data/processed/raw_data.csv", index=False)

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### ➕ COMBINE - ALL DATASET

# %% [markdown]
# <hr>
#
# ## DATA EXPLORATION
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔻 LOAD - COMBINED RAW DATA

# %%
# load raw_data CSV in df
df = pd.read_csv("../data/processed/raw_data.csv")

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲 DISPLAY - HEAD

# %%
# Display df DataFrame
print("DATA EXPLORATION:")
display(df.head(10))
print("External Dataset Shape:", df.shape[0], "rows and", df.shape[1], "columns\n")

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲 DISPLAY - UNIQUE VALUES

# %%
# Display data types & missing values of each column in df
print("Data Types & Missing Values of Each Column:")
display(df.info())

# Loop through each column and print unique values
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"Column: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}\n")

print(f"\nData types check:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    print(f"  ➡️{col:<25} {str(dtype):<10} [{unique_vals}] unique values")

# %% [markdown]
# <hr>
#
# ## CLEANING OVERVIEW
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# Note observations and changes to be made on the data:
# - note a
# - note b
# - note c
# - change 1
# - change 2
# - change 3

# %% [markdown]
# <hr>
#
# ## 1 - STANDARDIZE NAMES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### DROP - COLUMNS

# %%
# drop columns that are not relevant for analysis

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### RENAME - COLUMNS

# %% [markdown]
# | Original Column Name        | Standardized Column Name        |
# |----------------------------|----------------------------------|
# | `col_1`           | `standard_col_1`                         |
# | `col_2`  | `standard_col_2`                |

# %%
import pandas as pd

# Load main dataset
df = pd.read_csv("../data/raw/external_data.csv")

# Define the Renaming Dictionary
rename_columns = {
    "col_1": "standard_col_1",
    "col_2": "standard_col_2"
}

# Rename columns using the rename Dictionary
df.rename(columns=rename_columns, inplace=True)

# Save updated dataset into a new CSV file
df.to_csv("../data/processed/01_.csv", index=False)

# Display Standardized DataFrame
print("Standardized DataFrame:")
display(df.head())

# Display the list of the standardized column names in df
print("Standardized Column Names:")
display(df.info())

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 💾 SAVE - STANDARDIZED DF

# %%
df.to_csv("../data/processed/standard_data.csv", index=False)

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲 DISPLAY - STANDARDIZED DF

# %%
# Display Standardized DataFrame
print("Standardized DataFrame:")
display(df.head(10))
print("Standardized Dataset Shape:", df.shape[0], "rows and", df.shape[1], "columns")

# %% [markdown]
# <hr>
#
# ## 4 - INVALID VALUES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲 LOAD - STANDARDIZED CSV in DF

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🔲 DISPLAY - UNIQUE VALUES

# %%
# Loop through each column and print unique values
print(100 * "-")
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"➡️ {col} ({len(unique_vals)}) 🧾 unique values:")
    print(f"{unique_vals}")
    print(100 * "-")

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### PRINT - MIN & MAX

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### FIX - INVALID VALUES

# %% [markdown]
# <hr>
#
# ## 5 - DATA TYPES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🔲 DISPLAY - DATA TYPES

# %%
# print data types and unique values count for each column in df
print(f"\nData types check:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    print(f"  ➡️{col:<25} {str(dtype):<10} [{unique_vals}] unique values")

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### CONVERT - DATA TYPES

# %% [markdown]
# <hr>
#
# ## 6 - NULL VALUES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🔲 DISPLAY - COLs with NULLS & Missing Values

# %% [markdown]
# Using df.info() and/or a loop to check for null values in each column:

# %%
# Loop through each column and print the number of nulls in each column
for col in df.columns:
    null_count = df[col].isnull().sum()
    print(f"[{col}]: [{null_count}] null values")

print(100*"-")
# display data types and missing values of each column in df
df.info()

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🫳 DROP - NULL VALUES

# %% [markdown]
# <hr>
#
# ## 7 - DUPLICATES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🔲 DISPLAY - DUPLICATE ROWS

# %%
# Check for duplicate rows in the DataFrame
duplicate_rows = df[df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")

# Display the duplicate rows if any exist
if not duplicate_rows.empty:
    print("\nDuplicate rows:")
    display(duplicate_rows)
else:
    print("\nNo duplicate  rows found.")

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 🫳 DROP - DUPLICATE ROWS

# %%
# drop duplicate rows in df
#df = df.drop_duplicates()

# %% [markdown]
# <hr>
#
# ## 8 - SAVE & REVISE CLEAN DATA
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 💾 SAVE - CLEAN DF

# %%
# save clean dataset in a new CSV file
df.to_csv("../data/processed/clean_data.csv", index=False)

# %% [markdown]
# ```text
# - display head
# - display info
# - check unique values
# - check data types
# - check for nulls
# - check for duplicates
# ```

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲🕵️ REVISE - CLEAN DF

# %%
# --------------------
# 🔲 DISPLAY - HEAD
# --------------------
# Display df DataFrame
print("Dataset Exploration:")
display(df.head(10))
print("External Dataset Shape:", df.shape[0], "rows and", df.shape[1], "columns\n")
print(100*"-")

# --------------------
# 🔲 DISPLAY - INFO
# --------------------
# display data types and missing values of each column in df
df.info()
print(100*"-")

# -----------------------------
# 🕵️ CHECK - UNIQUE VALUES
# -----------------------------
# Display data types & missing values of each column in df
print("Data Types & Missing Values of Each Column:")
display(df.info())

# Loop through each column and print unique values
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"Column: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}\n")
print(100*"-")

# -----------------------------
# 🕵️ CHECK - DATA TYPES
# -----------------------------
print(f"\nData types check:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    print(f"  ➡️{col:<25} {str(dtype):<10} [{unique_vals}] unique values")
print(100*"-")

# -----------------------------
# 🕵️ CHECK - NULLS
# -----------------------------
# Loop through each column and print the number of nulls in each column
for col in df.columns:
    null_count = df[col].isnull().sum()
    print(f"[{col}]: [{null_count}] null values")
print(100*"-")


# -----------------------------
# 🕵️ CHECK - DUPLICATES
# -----------------------------
# Check for duplicate rows in the DataFrame
duplicate_rows = df[df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
print(100*"-")

# Display the duplicate rows if any exist
if not duplicate_rows.empty:
    print("\nDuplicate rows:")
    display(duplicate_rows)
else:
    print("\nNo duplicate  rows found.")
print(100*"-")
