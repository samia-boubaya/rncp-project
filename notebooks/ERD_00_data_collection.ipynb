# %% [markdown]
# <hr>
#
# # ℹ️ DATA COLLECTION
#
#
# <style>
# h1 {
#     text-align: left;
#     color: blue;
#     font-weight: bold;
# }
#
# </style>
# <hr>

# %% [markdown]
# ```text
# DATA COLLECTION Steps:
#
# 0) Data Browsing - using data sources:
# - https://opendata.paris.fr/pages/home/
# - https://data.iledefrance.fr/pages/home-open-data/
# - https://data.gov.uk/ (not using it because i wanna focus on the French market)
#
# 1) Data Loading (.txt and .json to .csv and merge if multiple sources)
#
# 2) Data Exploration (understand data and take notes)
#
# 3) Data Selection (select columns to use or keep or not keep)
#
# 4) Data Validation (get sabina to validate the one merged dataset)
#
# ```

# %% [markdown]
# <style>
# h3 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# ### 📂 IMPORTs

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200) # to display all columns in the dataframe

# %% [markdown]
# <hr>
#
# ## 0 - DATA DOWNLOADING
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# download files from links

# links dictionary
links = {
    "arrondissements": "../data/raw/arrondissements.csv",
    "communes": "../data/raw/etablissements-adultes-handicap.csv",
    "residences-universitaires": "../data/raw/residences-universitaires-crous-en-ile-de-france.csv",
    "statuts-doccupation-des-residences-principales": "../data/raw/statuts-doccupation-des-residences-principales-des-communes-donnee-insee.csv",
    "lignes-de-transport-en-commun": "../data/raw/traces-des-lignes-de-transport-en-commun-idfm.csv",
    "ValeursFoncieres-2020-S2": "../data/raw/ValeursFoncieres-2020-S2.txt",    
    "ValeursFoncieres-2021": "../data/raw/ValeursFoncieres-2021.txt",    
    "ValeursFoncieres-2022": "../data/raw/ValeursFoncieres-2022.txt",    
    "ValeursFoncieres-2023": "../data/raw/ValeursFoncieres-2023.txt",    
    "ValeursFoncieres-2024": "../data/raw/ValeursFoncieres-2024.txt",    
    "ValeursFoncieres-2025": "../data/raw/ValeursFoncieres-2025-S1.txt"
}

# %% [markdown]
# <hr>
#
# ## 1 - DATA LOADING
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# links dictionary
links = {
    "arrondissements": "../data/raw/arrondissements.csv",
    "communes": "../data/raw/etablissements-adultes-handicap.csv",
    "residences-universitaires": "../data/raw/residences-universitaires-crous-en-ile-de-france.csv",
    "statuts-doccupation-des-residences-principales": "../data/raw/statuts-doccupation-des-residences-principales-des-communes-donnee-insee.csv",
    "lignes-de-transport-en-commun": "../data/raw/traces-des-lignes-de-transport-en-commun-idfm.csv",
    "ValeursFoncieres-2020-S2": "../data/raw/ValeursFoncieres-2020-S2.txt",    
    "ValeursFoncieres-2021": "../data/raw/ValeursFoncieres-2021.txt",    
    "ValeursFoncieres-2022": "../data/raw/ValeursFoncieres-2022.txt",    
    "ValeursFoncieres-2023": "../data/raw/ValeursFoncieres-2023.txt",    
    "ValeursFoncieres-2024": "../data/raw/ValeursFoncieres-2024.txt",    
    "ValeursFoncieres-2025": "../data/raw/ValeursFoncieres-2025-S1.txt"
}

# load each file into a dataframe and store in a dictionary

df_arrondissements = pd.read_csv(links["arrondissements"], sep=";")
df_communes = pd.read_csv(links["communes"], sep=";")
df_residences_universitaires = pd.read_csv(links["residences-universitaires"], sep=";")
df_statuts_occupation = pd.read_csv(links["statuts-doccupation-des-residences-principales"], sep=";")
df_lignes_transport = pd.read_csv(links["lignes-de-transport-en-commun"], sep=";")
df_valeurs_foncieres_2020 = pd.read_csv(links["ValeursFoncieres-2020-S2"], sep="|\t")
df_valeurs_foncieres_2021 = pd.read_csv(links["ValeursFoncieres-2021"], sep="|\t")
df_valeurs_foncieres_2022 = pd.read_csv(links["ValeursFoncieres-2022"], sep="|\t")
df_valeurs_foncieres_2023 = pd.read_csv(links["ValeursFoncieres-2023"], sep="|\t")
df_valeurs_foncieres_2024 = pd.read_csv(links["ValeursFoncieres-2024"], sep="|\t")
df_valeurs_foncieres_2025 = pd.read_csv(links["ValeursFoncieres-2025"], sep="|\t")



print("All dataframes loaded successfully!")

# %%
import pandas as pd



# ----------------------
# COMMUNE DATA
# ----------------------

df_arrondissements = pd.read_csv("../data/raw/arrondissements.csv", sep=";")

# ----------------------
# COMMUNE DATA
# ----------------------
df_communes = pd.read_csv("../data/raw/etablissements-adultes-handicap.csv", sep=";")

# -------------------------------
# RESIDENCES UNIVERSITAIRES DATA
# -------------------------------
df_residences_universitaires = pd.read_csv("../data/raw/residences-universitaires-crous-en-ile-de-france.csv", sep=";")

# ------------------------------------
# STATUS D'OCCUPATION DATA
# ------------------------------------
df_statuts_occupation = pd.read_csv("../data/raw/statuts-doccupation-des-residences-principales-des-communes-donnee-insee.csv", sep=";")


# ----------------------
# TRANSPORT DATA
# ----------------------
df_lignes_transport = pd.read_csv("../data/raw/traces-des-lignes-de-transport-en-commun-idfm.csv", sep=";")


# ----------------------
# DVF DATA
# ----------------------
# DVF files are separated by pipe and tab, so we need to specify both as separators
# Read the .txt file with pipe separator
# df = pd.read_csv("file.txt", sep="|")
df_valeurs_foncieres_2020 = pd.read_csv("../data/raw/ValeursFoncieres-2020-S2.txt", sep="|",low_memory=True, dtype=str)
df_valeurs_foncieres_2021 = pd.read_csv("../data/raw/ValeursFoncieres-2021.txt", sep="|", low_memory=True, dtype=str)
df_valeurs_foncieres_2022 = pd.read_csv("../data/raw/ValeursFoncieres-2022.txt", sep="|", low_memory=True, dtype=str)
df_valeurs_foncieres_2023 = pd.read_csv("../data/raw/ValeursFoncieres-2023.txt", sep="|", low_memory=True, dtype=str)
df_valeurs_foncieres_2024 = pd.read_csv("../data/raw/ValeursFoncieres-2024.txt", sep="|", low_memory=True, dtype=str)
df_valeurs_foncieres_2025 = pd.read_csv("../data/raw/ValeursFoncieres-2025-S1.txt", sep="|", low_memory=True, dtype=str)

# Concat all DVF dataframes into one
df_valeurs_foncieres = pd.concat([df_valeurs_foncieres_2020, df_valeurs_foncieres_2021, df_valeurs_foncieres_2022, df_valeurs_foncieres_2023, df_valeurs_foncieres_2024, df_valeurs_foncieres_2025], ignore_index=True)
# Save as CSV
df_valeurs_foncieres.to_csv("../data/processed/ValeursFoncieres_2020-S2_2025-S1.csv", index=False)

# %% [markdown]
# <hr>
#
# ## 2 - DATA EXPLORATION
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# display all dataframes to check if they are loaded correctly
print("Arrondissements:")
display(df_arrondissements.head())
print(100*"-")

print("Communes:")
display(df_communes.head())
print(100*"-")

print("Résidences Universitaires:")
display(df_residences_universitaires.head())
print(100*"-")

print("Statuts d'occupation des résidences principales:")
display(df_statuts_occupation.head())
print(100*"-")

print("Lignes de transport en commun:")
display(df_lignes_transport.head())
print(100*"-")

print("Valeurs Foncières 2020_S2 - 2025_S1:")
display(df_valeurs_foncieres.head())
print(100*"-")

# %% [markdown]
# <hr>
#
# ## 3 - DATA TRANSFORMATION
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <hr>
#
# ## 3 - DATA SELECTION
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <hr>
#
# ## 4 - DATA VALIDATION
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# ```text
# Gotta Get data validated by Sabina.
# ```
