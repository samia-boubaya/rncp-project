# %% [markdown]
# <hr>
#
# # ⚗️ DATA PREPROCESSING
#
#
# <style>
# h1 {
#     text-align: left;
#     color: green;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# ```text
# 1. Data Preparation for Machine Learning
# 2. Train-Test SPLIT (80% Train / 20% Test) using stratify to keep same balance
# 3. Feature Engineering & Feauture Scaling (Cat/Num)
# 4. Imbalance handling (check if data is imbalanced)
# ```

# %% [markdown]
# |    column              | categorical vs numeric            | Variable Type                  |
# | ---------------------- | --------------------------------- |----------------------|
# | transaction_date       | date                              ||
# | transaction_type       | categorical                       ||
# | property_value         | numeric                           |Target|
# | street_number          | categorical                       ||
# | btq_code               | categorical                       ||
# | street_name            | categorical                       | |
# | postal_code            | categorical                       ||
# | commune_name           | categorical                       | |
# | number_of_lots         | numeric                           ||
# | property_type          | categorical                       ||
# | building_real_surface  | numeric                           ||
# | main_rooms_count       | numeric                           ||
# | land_surface           | numeric                           ||
# | effective_surface      | numeric                           ||
# | value_per_m2           | numeric                           |Calculated Target|
# | surface_type           | categorical                       ||
# | department_code        | categorical                       ||
