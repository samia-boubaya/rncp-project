# %% [markdown]
# <hr>
#
# ## BEFORE
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# | Original Column Name          |      Standardized        | Description                                      |
# | ----------------------------- | ------------------------ |------------------------------------------------- |
# | **Date mutation**             | `transaction_date`       | Date when the property was sold                  |
# | **Nature mutation**           | `transaction_type`       | Nature of transaction (sale, donation, etc.)     |
# | **Valeur fonciere**           | `property_value`         | Transaction price in euros                       |
# | **No voie**                   | `street_number`          | Street number of the property                    |
# | **B/T/Q**                     | `btq_code`               | Bâtiment/Type/Quartier code for identification   |
# | **Voie**                      | `street_name`            | Full street name                                 |
# | **Code postal**               | `postal_code`            | Postal code (categorical, not numeric)           |
# | **Commune**                   | `com_name`               | Commune name                                     |
# | **Nombre de lots**            | `number_of_lots`         | Number of lots in the property                   |
# | **Type local**                | `property_type`          | Property type (Apartment, House, etc.)           |
# | **Surface reelle bati**       | `building_real_surface`  | Built area in square meters                      |
# | **Nombre pieces principales** | `main_rooms_count`       | Number of main rooms (living / bedrooms)         |
# | **Surface terrain**           | `land_surface`           | Land area in square meters                       |
#
#
# **TO BE ADDED LATER AFTER CLEANING**
#
# | Column Name        | Description                                                                 |
# |--------------------|-----------------------------------------------------------------------------|
# | `com_type`         | Commune type ['COM' 'COMD' 'COMA' 'ARM']  |
# | `insee_code`       | INSEE 5-digit code which is combination `dep_code`=DD & `com_code`=CCC insee_code=**DDCCC**                  |
# | `com_code`         | INSEE commune 3-digit code derived from `df_com_dep` using `com_name` mapping       |
# | `dep_code`         | INSEE department 2-digit code derived from `df_com_dep` using `com_name` mapping      |
# | `dep_name`         | INSEE department name derived from `df_com_dep` `dep_name` mapping                |
# | `surface_type`     | Indicates whether surface comes from built area or land                     |
# | `surface_m2`          | Effective surface used for calculating price/m² (built or land fallback)    |
# | `value_per_m2`     | Property value per square meter (**€ / m²**)                                    |

# %% [markdown]
# <hr>
#
# ## AFTER (final table)
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# **FINAL TABLE**
#
# | Column Name        | Description                                                                 |
# |--------------------|-----------------------------------------------------------------------------|
# |`transaction_date`       | Date when the property was sold                  |
# |`transaction_type`       | Nature of transaction (sale, donation, etc.)     |
# |`property_value`         | Transaction price in euros                       |
# |`street_number`          | Street number of the property                    |
# |`btq_code`               | Bâtiment/Type/Quartier code for identification   |
# |`street_name`            | Full street name                                 |
# |`postal_code`            | Postal code (categorical, not numeric)           |
# |`com_name`               | Commune name                                     |
# | `dep_code`         | INSEE department 2-digit code derived from `df_com_dep` using `com_name` mapping      |
# | `com_code`         | INSEE commune 3-digit code derived from `df_com_dep` using `com_name` mapping       |
# |`number_of_lots`         | Number of lots in the property                   |
# |`property_type`          | Property type (Apartment, House, etc.)           |
# |`building_real_surface`  | Built area in square meters                      |
# |`main_rooms_count`       | Number of main rooms (living / bedrooms)         |
# |`land_surface`           | Land area in square meters                       |
# | `com_type`         | Commune type ['COM' 'COMD' 'COMA' 'ARM']  |
# | `insee_code`       | INSEE 5-digit code which is combination `dep_code`=DD & `com_code`=CCC insee_code=**DDCCC**                  |
# | `dep_name`         | INSEE department name derived from `df_com_dep` `dep_name` mapping                |
# | `surface_type`     | Indicates whether surface comes from built area or land                     |
# | `surface`          | Effective surface used for calculating price/m² (built or land fallback)    |
# | `value_per_m2`     | Property value per square meter (**€ / m²**)                                    |
