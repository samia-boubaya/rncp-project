# %% [markdown]
# <hr>
#
# # 🤔 HYPOTHESIS TESTING
#
#
# <style>
# h1 {
#     text-align: left;
#     color: blue;
#     font-weight: bold;
# }
#
# </style>
# <hr>

# %% [markdown]
# ```text
# Types of Test to check relationships:
# - Z test
# - T test
# ```
