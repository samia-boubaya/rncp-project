# %% [markdown]
# <hr>
#
# # ℹ️ DATA EXPLORATION
#
#
# <style>
# h1 {
#     text-align: left;
#     color: blue;
#     font-weight: bold;
# }
#
# </style>
# <hr>

# %% [markdown]
# ## **FlatFiles: 💰 VALEURS FONCIERES 2020-2025**

# %% [markdown]
# What it contains:
# - Transaction date (2020-S2 to 2025-S1)
# - Transaction type: Sale, Exchange, Sale ...
# - Transaction value in (€)
# - Property type (apartment, house, Industrial, Outbuilding ...)
# - Property surface (m²)
# - Surface type: building, land, or combined
# - Main rooms count
# - Lots count
# - Exact address (geocodable): insee_code, longitude, latitude
#
# We analyse:
# - 📈 Market growth over 5–6 years (Historical value evolution)
# - 🏠 Difference between different types of properties: houses vs apartments vs ...
# - 📉 Market dips (e.g., COVID effects, gaz inflation...)
# -
#
# We use it to:
# - 📊 Analyse Market trends
# - 🤖 Build ML MODEL to predict TARGET VARIABLE 🎯 (`property_value`) based on input:
#     - location,
#     - property_type,
#     - location_type,
#     - budget,
#     - rental_price,

# %% [markdown]
# ---
# ## **WEB SCRAPE: 🌍 Property Listings on SeLoger.com**

# %% [markdown]
# What it contains:
# - Date_listed
# - property_reference
# - address: insee_code, longitude, latitude of property
# - price_hors_charges
# - price_charges
# - price_charges_included
# - type_charges: individuel ou collectif
# - type_chauffage: electrique ou gaz
#
# - property_type: apartment, house, industrial, outbuilding
# - property_surface
# - property_size:
#     - main_rooms_count
#     - lots_count
# -

# %% [markdown]
# ---
# ## **API: 🌍 LONGITUTDE & LATITUDE**

# %% [markdown]
# What it contains:
# - Latitude & longitude boundaries
# - Arrondissements polygons
# - Commune mapping
# - INSEE codes

# %% [markdown]
# <style>
# h4 {
#     margin-top: 0px;
#     margin-bottom: 0px;
#     font-weight: bold;
# }
# </style>
#
# #### 🔲 DATASET

# %% [markdown]
# | Field Name             | Python Data Type       | Concise Definition                                  |
# |------------------------|------------------------|-----------------------------------------------------|

# %%
# api for paris / outside paris
# arrondissements boundaries
# communes ile de france boundaries

# %% [markdown]
# ---
# ## **API: 💲RENTAL PRICE**
#
# **`API_RENTAL.CSV`**

# %% [markdown]
# What it contains:
# - Median rent (€ / month)
# - Rent per m²
# - Vacancy rate (%)
# - Rent evolution over time
# - Data by arrondissement / commune

# %%
# api for rental prices
